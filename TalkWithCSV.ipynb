# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanidotcom/TalkWithCSV/blob/main/TalkWithCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: install langchain

# !pip install langchain

# %%
# prompt: install open ai


# !pip install openai

# %%
# !pip install langchain-community
from langchain.document_loaders import CSVLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
import os
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# ...

# %%
os.environ["OPENAI_API_KEY"] = "api-key"

# %%
import pandas as pd
print(os.getcwd())
df=pd.read_csv('/content/pokemon.csv')
df.head()
# Out:
# /content
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# prompt: ERROR: Could  not find a version that satisfies the requirement lanchain-experimental (from versions: none)
# ERROR: No matching distribution found for lanchain-experimental

# !pip install langchain-experimental

# %%
from langchain_experimental.agents import create_csv_agent
from langchain.llms import OpenAI

# %%
api_key="api-key"
input_agent=create_csv_agent(
    OpenAI(temperature=0,openai_api_key=api_key),
    '/content/pokemon.csv',
    verbose=True,allow_dangerous_code=True
)

# %%
print(input_agent.agent.runnable.steps[1])
# Out:
# input_variables=['agent_scratchpad', 'input'] input_types={} partial_variables={'df_head': '|    |   # | Name                  | Type 1   | Type 2   |   Total |   HP |   Attack |   Defense |   Sp. Atk |   Sp. Def |   Speed |   Generation | Legendary   |\n|---:|----:|:----------------------|:---------|:---------|--------:|-----:|---------:|----------:|----------:|----------:|--------:|-------------:|:------------|\n|  0 |   1 | Bulbasaur             | Grass    | Poison   |     318 |   45 |       49 |        49 |        65 |        65 |      45 |            1 | False       |\n|  1 |   2 | Ivysaur               | Grass    | Poison   |     405 |   60 |       62 |        63 |        80 |        80 |      60 |            1 | False       |\n|  2 |   3 | Venusaur              | Grass    | Poison   |     525 |   80 |       82 |        83 |       100 |       100 |      80 |            1 | False       |\n|  3 |   3 | VenusaurMega Venusaur | Grass    | Poison   |     625 |   80 |      100 |     
# ...

# %%
input_agent.run("how many rows are there?")
